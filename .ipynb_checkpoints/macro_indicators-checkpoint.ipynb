# %%
#%% Importing modules and data
import smtplib
import pandas as pd
import numpy as np
import datetime as dt
import pandas.stats.moments as st
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import os
import quandl
import seaborn as sns
import matplotlib.dates as dates
import matplotlib.ticker as ticker
from pandas_datareader import data
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

def save_xls(list_dfs, xls_path,sheet_names):
    writer = ExcelWriter(xls_path)
    for n, df in enumerate(list_dfs):
        df.to_excel(writer, sheet_names[n])
    writer.save()
    return

# %%
### Collecting data

spx = pd.read_csv('SPX.csv')
spx['Date'] = pd.to_datetime(spx['Date'])
spx = spx.set_index(['Date'])
spx = spx[['Close']]
spx.columns = ['spx']

# Economic data from Quandl

#unemployment_rate = quandl.get("FRED/NROUST", authtoken="-ZxrLoLy3vKgLtLraaMn")
#total_fed_debt = quandl.get("FRED/GFDEBTN", authtoken="-ZxrLoLy3vKgLtLraaMn")
#fed_debt_public_held = quandl.get("FRED/FYGFDPUN", authtoken="-ZxrLoLy3vKgLtLraaMn")
#public_debt_to_gdp = quandl.get("FRED/GFDEGDQ188S", authtoken="-ZxrLoLy3vKgLtLraaMn")
#household_debt_to_gdp = quandl.get("FRED/HDTGPDUSQ163N", authtoken="-ZxrLoLy3vKgLtLraaMn")
#industrial_production_final = quandl.get("FRED/IPB50002NQ", authtoken="-ZxrLoLy3vKgLtLraaMn")


# Investing for a Living 6 macro factors
civ_unemployment_rate = quandl.get("FRED/UNRATE", authtoken="-ZxrLoLy3vKgLtLraaMn")
civ_unemployment_rate.columns = ['civ_unemployment_rate']

real_retail_and_services = quandl.get("FRED/RRSFS", authtoken="-ZxrLoLy3vKgLtLraaMn")
real_retail_and_services.columns = ['real_retail_and_services']

industrial_production_consumer_goods = quandl.get("FRED/IPDCONGD", authtoken="-ZxrLoLy3vKgLtLraaMn")
industrial_production_consumer_goods.columns = ['industrial_production_consumer_goods']

new_housing = quandl.get("FRED/PERMIT", authtoken="-ZxrLoLy3vKgLtLraaMn")
new_housing.columns = ['new_housing']

yield_spread = quandl.get("FRED/T10Y3MM", authtoken="-ZxrLoLy3vKgLtLraaMn")
yield_spread.columns = ['yield_spread']

national_fin_conditions = quandl.get("FRED/NFCILEVERAGE", authtoken="-ZxrLoLy3vKgLtLraaMn")
national_fin_conditions.columns = ['national_fin_conditions']
national_fin_conditions['Date'] = 0

curr_month = 0
for index, row in national_fin_conditions.iterrows():
    if index.month == curr_month:
        national_fin_conditions.drop(index, inplace=True)
    else:
        curr_year = index.year
        curr_month = index.month
        national_fin_conditions.ix[index, 1] = dt.datetime(curr_year, curr_month, 1)
    curr_month = index.month
national_fin_conditions['Date'] = pd.to_datetime(national_fin_conditions['Date'])
national_fin_conditions = national_fin_conditions.set_index(['Date'])

df = pd.concat([spx, civ_unemployment_rate, real_retail_and_services,
               industrial_production_consumer_goods, new_housing,
               yield_spread, national_fin_conditions], axis = 1).dropna()
# Out:
# C:\Users\Fang\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
# Scaling Data
sc_function = StandardScaler()
df_scaled = sc_function.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled)
df_scaled = df_scaled.set_index(df.index)
df_scaled.columns = df.columns

# %%
df_scaled[['spx','national_fin_conditions','civ_unemployment_rate']].plot(figsize = (20,10))
plt.title('SPX vs National Financial Conditions vs Civilian Unemployment Rate', fontsize = 20)

# %%
df_scaled[['spx','real_retail_and_services','industrial_production_consumer_goods']].plot(figsize = (20,10))
plt.title('SPX vs Real Retail and Services vs Industrial Production Consumer Goods', fontsize = 20)

# %%
df_scaled[['spx','new_housing','yield_spread']].plot(figsize = (20,10))
plt.title('SPX vs New Housing Permits vs Treasury 10 Year Minus 3 Month Spread', fontsize = 20)

# %%
df[['spx_returns','civ_unemployment_rate', 'real_retail_and_services',
   'industrial_production_consumer_goods', 'new_housing',
   'yield_spread', 'national_fin_conditions']].corr()
# Out:
#                                       spx_returns  civ_unemployment_rate  \
# spx_returns                              1.000000               0.055725
# civ_unemployment_rate                    0.055725               1.000000
# real_retail_and_services                -0.050440              -0.098984
# industrial_production_consumer_goods    -0.061170              -0.544278
# new_housing                             -0.006401              -0.736025
# yield_spread                            -0.051265               0.678365
# national_fin_conditions                 -0.079598               0.149931
#
#                                       real_retail_and_services  \
# spx_returns                                          -0.050440
# civ_unemployment_rate                                -0.098984
# real_retail_and_services                              1.000000
# industrial_production_consumer_goods                  0.784080
# new_housing                                          -0.034904
# yield_spread                                         -0.149349
# national_fin_conditions                               0.136986
#
#                                       industrial_production_consumer_goods  \
# spx_returns                                                      -0.061170
# civ_unemployment_rate                                            -0.544278
# real_retail_and_services                                          0.784080
# industrial_production_consumer_goods                              1.000000
# new_housing                                                       0.530897
# yield_spread                                                     -0.369539
# national_fin_conditions                                          -0.001047
#
#                                       new_housing  yield_spread  \
# spx_returns                             -0.006401     -0.051265
# civ_unemployment_rate                   -0.736025      0.678365
# real_retail_and_services                -0.034904     -0.149349
# industrial_production_consumer_goods     0.530897     -0.369539
# new_housing                              1.000000     -0.384381
# yield_spread                            -0.384381      1.000000
# national_fin_conditions                 -0.318593     -0.018037
#
#                                       national_fin_conditions
# spx_returns                                         -0.079598
# civ_unemployment_rate                                0.149931
# real_retail_and_services                             0.136986
# industrial_production_consumer_goods                -0.001047
# new_housing                                         -0.318593
# yield_spread                                        -0.018037
# national_fin_conditions                              1.000000

# %%
test_df = df.pct_change().dropna()

# %%
test_df.corr()
# Out:
#                                            spx  civ_unemployment_rate  \
# spx                                   1.000000              -0.094407
# civ_unemployment_rate                -0.094407               1.000000
# real_retail_and_services              0.210107              -0.042411
# industrial_production_consumer_goods  0.024831              -0.135382
# new_housing                           0.100356              -0.085623
# yield_spread                          0.025209              -0.019522
# national_fin_conditions              -0.063781               0.050072
#
#                                       real_retail_and_services  \
# spx                                                   0.210107
# civ_unemployment_rate                                -0.042411
# real_retail_and_services                              1.000000
# industrial_production_consumer_goods                  0.055928
# new_housing                                           0.230440
# yield_spread                                          0.038071
# national_fin_conditions                               0.022367
#
#                                       industrial_production_consumer_goods  \
# spx                                                               0.024831
# civ_unemployment_rate                                            -0.135382
# real_retail_and_services                                          0.055928
# industrial_production_consumer_goods                              1.000000
# new_housing                                                       0.083290
# yield_spread                                                     -0.053635
# national_fin_conditions                                          -0.014135
#
#                                       new_housing  yield_spread  \
# spx                                      0.100356      0.025209
# civ_unemployment_rate                   -0.085623     -0.019522
# real_retail_and_services                 0.230440      0.038071
# industrial_production_consumer_goods     0.083290     -0.053635
# new_housing                              1.000000      0.040434
# yield_spread                             0.040434      1.000000
# national_fin_conditions                 -0.020241      0.024132
#
#                                       national_fin_conditions
# spx                                                 -0.063781
# civ_unemployment_rate                                0.050072
# real_retail_and_services                             0.022367
# industrial_production_consumer_goods                -0.014135
# new_housing                                         -0.020241
# yield_spread                                         0.024132
# national_fin_conditions                              1.000000

# %%
df.to_csv('macro.csv')

# %%
'''
unemployment rate >= 5
yield spreads > 1.5 or 2
financial conditions leverage >= 1.5


'''
# Out:
# '\nunemployment rate >= 5\nyield spreads > 1.5 or 2\nfinancial conditions leverage >= 1.5\n\n\n'

# %% [markdown]
# # China Economic Data

# %%
### Collecting data

spx = pd.read_csv('SPX.csv')
spx['Date'] = pd.to_datetime(spx['Date'])
spx = spx.set_index(['Date'])
spx = spx[['Close']]
spx.columns = ['spx']

vxo = pd.read_csv('http://www.cboe.com/publish/scheduledtask/mktdata/datahouse/vixcurrent.csv',skiprows=1).dropna()
vxo['Date'] = pd.to_datetime(vxo['Date'])
vxo = vxo.set_index(['Date'])
vxo = vxo[['VIX Close']]
vxo.columns = ['vxo']

# Economic data from Quandl

#unemployment_rate = quandl.get("FRED/NROUST", authtoken="-ZxrLoLy3vKgLtLraaMn")
#total_fed_debt = quandl.get("FRED/GFDEBTN", authtoken="-ZxrLoLy3vKgLtLraaMn")
#fed_debt_public_held = quandl.get("FRED/FYGFDPUN", authtoken="-ZxrLoLy3vKgLtLraaMn")
#public_debt_to_gdp = quandl.get("FRED/GFDEGDQ188S", authtoken="-ZxrLoLy3vKgLtLraaMn")
#household_debt_to_gdp = quandl.get("FRED/HDTGPDUSQ163N", authtoken="-ZxrLoLy3vKgLtLraaMn")
#industrial_production_final = quandl.get("FRED/IPB50002NQ", authtoken="-ZxrLoLy3vKgLtLraaMn")


# Investing for a Living 6 macro factors
usdrmb = quandl.get("DY2/M1080000235", authtoken="-ZxrLoLy3vKgLtLraaMn")
usdrmb.columns = ['usdrmb']

manufacturingPMI = quandl.get("DY2/M1030000011", authtoken="-ZxrLoLy3vKgLtLraaMn")
manufacturingPMI.columns = ['manufacturingPMI']

ConfidenceIndex = quandl.get("DY2/M1030000138", authtoken="-ZxrLoLy3vKgLtLraaMn")
ConfidenceIndex.columns = ['ConfidenceIndex']

BaseCurrencyBalance = quandl.get("DY2/M1070000030", authtoken="-ZxrLoLy3vKgLtLraaMn")
BaseCurrencyBalance.columns = ['BaseCurrencyBalance']

LogisticsProsperityIndex = quandl.get("DY2/M1030000052", authtoken="-ZxrLoLy3vKgLtLraaMn")
LogisticsProsperityIndex.columns = ['LogisticsProsperityIndex']

MacroeconomicProsperityIndex = quandl.get("DY2/M1030000075", authtoken="-ZxrLoLy3vKgLtLraaMn")
MacroeconomicProsperityIndex.columns = ['MacroeconomicProsperityIndex']

china_df = pd.concat([spx, vxo, usdrmb, manufacturingPMI,
               ConfidenceIndex, BaseCurrencyBalance,
               LogisticsProsperityIndex, MacroeconomicProsperityIndex], axis = 1).dropna()

# %%
# Scaling Data
sc_function = StandardScaler()
china_df_scaled = sc_function.fit_transform(china_df)
china_df_scaled = pd.DataFrame(china_df_scaled)
china_df_scaled = china_df_scaled.set_index(china_df.index)
china_df_scaled.columns = china_df.columns

# %%
china_df_scaled[['spx','vxo','usdrmb']].plot(figsize = (20,10))
plt.title('SPX vs VXO vs usdrmb', fontsize = 20)

# %%
china_df_scaled[['spx','vxo','manufacturingPMI']].plot(figsize = (20,10))
plt.title('SPX vs VXO vs manufacturingPMI', fontsize = 20)

# %%
china_df_scaled[['spx','vxo','ConfidenceIndex']].plot(figsize = (20,10))
plt.title('SPX vs VXO vs ConfidenceIndex', fontsize = 20)

# %%
china_df_scaled[['spx','vxo','LogisticsProsperityIndex']].plot(figsize = (20,10))
plt.title('SPX vs VXO vs LogisticsProsperityIndex', fontsize = 20)

# %%
china_df_scaled[['spx','vxo','MacroeconomicProsperityIndex']].plot(figsize = (20,10))
plt.title('SPX vs VXO vs MacroeconomicProsperityIndex', fontsize = 20)

# %%
china_df.to_csv('chinamacro.csv')
